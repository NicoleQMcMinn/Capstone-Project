# %%
import pandas as pd

# %%
amazon = pd.read_csv('amazon-purchases.csv')
demogs = pd.read_csv('survey.csv')

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850717 entries, 0 to 1850716
# Data columns (total 8 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Order Date                object
#  1   Purchase Price Per Unit   float64
#  2   Quantity                  float64
#  3   Shipping Address State    object
#  4   Title                     object
#  5   ASIN/ISBN (Product Code)  object
#  6   Category                  object
#  7   Survey ResponseID         object
# dtypes: float64(2), object(6)
# memory usage: 113.0+ MB

# %%
amazon.head(10)
# Out:
#    Order Date  Purchase Price Per Unit  Quantity Shipping Address State  \
# 0  2018-12-04                     7.98       1.0                     NJ
# 1  2018-12-22                    13.99       1.0                     NJ
# 2  2018-12-24                     8.99       1.0                     NJ
# 3  2018-12-25                    10.45       1.0                     NJ
# 4  2018-12-25                    10.00       1.0                     NJ
# 5  2019-02-18                    10.99       1.0                     NJ
# 6  2019-02-18                     4.99       1.0                     NJ
# 7  2019-03-15                   124.99       1.0                     NJ
# 8  2019-04-23                    12.99       1.0                     NJ
# 9  2019-04-23                    24.69       1.0                     NJ
#
#                                                Title ASIN/ISBN (Product Code)  \
# 0  SanDisk Ultra 16GB Class 10 SDHC UHS-I Memory ...               B0143RTB1E
# ...

# %%
unique_categories = amazon.Category.unique()

# %%
for i in unique_categories:
    print(i)
# Out:
# FLASH_MEMORY
# HEADPHONES
# nan
# DISHWARE_BOWL
# SHAVING_AGENT
# COMPUTER_PROCESSOR
# COMPUTER_ADD_ON
# AMAZON_TABLET
# APPAREL_BELT
# PORTABLE_ELECTRONIC_DEVICE_STAND
# IMMERSION_HEATER
# BODY_LUBRICANT
# INPUT_MOUSE
# CELLULAR_PHONE_CASE
# BODY_POSITIONER
# HANDBAG
# UNDERPANTS
# TAPE_MEASURE
# AMAZON_TABLET_ACCESSORY
# COMPUTER_DRIVE_OR_STORAGE
# TOOTH_CLEANING_AGENT
# TOILET_PAPER
# MOUTHWASH
# ELECTRONIC_CABLE
# SCREWDRIVER
# GIFT_CARD
# EDIBLE_OIL_VEGETABLE
# SIM_CARD
# BED_FRAME
# HERB
# MEAT
# DAIRY_BASED_BUTTER
# DAIRY_BASED_CHEESE
# JERKY
# SEXUAL_STIMULATION_DEVICE
# FILE_FOLDER
# SCREEN_PROTECTOR
# PORTABLE_ELECTRONIC_DEVICE_COVER
# MEMORY_CARD_READER
# STORAGE_BAG
# INKJET_PRINTER_INK
# CHAIR
# CONSUMER_ELECTRONICS
# CELLULAR_PHONE
# VIDEO_GAME_CONSOLE
# FLAT_SCREEN_DISPLAY_MOUNT
# GROCERY
# FOOD
# POULTRY
# JUICE_AND_JUICE_DRINK
# WIRELESS_ACCESSORY
# SUGAR_SUBSTITUTE
# PET_FOOD
# TOWEL
# TIMER
# WRIST_REST
# HEALTH_PERSONAL_CARE
# CULINARY_SALT
# SKIN_CLEANING_WIPE
# ...

# %%
amazon['Category'].nunique()
# Out:
# 1871

# %%
amazon['ASIN/ISBN (Product Code)'].nunique()
# Out:
# 939082
